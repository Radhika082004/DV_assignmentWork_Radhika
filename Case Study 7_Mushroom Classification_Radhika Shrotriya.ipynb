# %%
#Importing Modules and printing data

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
data=pd.read_csv("C:/Users/radhi/OneDrive/Desktop/mushrooms.csv")
data
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %%
#Simple EDA
data.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %%
data.tail()
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 8119            c         b          y  ...                        s
# 8120            c         b          y  ...                        s
# 8121            c         b          n  ...                        s
# 8122            c         n          b  ...                        k
# 8123            c         b          y  ...                        s
#
#      stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# ...

# %%
#For technical summary
#For identifying numerical and catagorical value
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   object
#  1   cap-shape                 8124 non-null   object
#  2   cap-surface               8124 non-null   object
#  3   cap-color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill-attachment           8124 non-null   object
#  7   gill-spacing              8124 non-null   object
#  8   gill-size                 8124 non-null   object
#  9   gill-color                8124 non-null   object
#  10  stalk-shape               8124 non-null   object
#  11  stalk-root                8124 non-null   object
#  12  stalk-surface-above-ring  8124 non-null   object
# ...

# %%
#For statistical summary (Mean , median , mode )
data.describe()
# Out:
#        class cap-shape cap-surface cap-color bruises  odor gill-attachment  \
# count   8124      8124        8124      8124    8124  8124            8124
# unique     2         6           4        10       2     9               2
# top        e         x           y         n       f     n               f
# freq    4208      3656        3244      2284    4748  3528            7914
#
#        gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# count          8124      8124       8124  ...                     8124
# unique            2         2         12  ...                        4
# top               c         b          b  ...                        s
# freq           6812      5612       1728  ...                     4936
#
#        stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# count                    8124                   8124      8124       8124
# unique                      9                      9         1          4
# ...

# %%
#Is there any null values present or not
data.isna()
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises   odor  \
# 0     False      False        False      False    False  False
# 1     False      False        False      False    False  False
# 2     False      False        False      False    False  False
# 3     False      False        False      False    False  False
# 4     False      False        False      False    False  False
# ...     ...        ...          ...        ...      ...    ...
# 8119  False      False        False      False    False  False
# 8120  False      False        False      False    False  False
# 8121  False      False        False      False    False  False
# 8122  False      False        False      False    False  False
# 8123  False      False        False      False    False  False
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0               False         False      False       False  ...
# 1               False         False      False       False  ...
# ...

# %%
#As there can be more values , so we will use this
data.isna().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
#For correlation
data.corr()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#Univariete Analysis
#For univariete analysis , we use histogram and box plot
data.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
# Generating a dataset with multiple columns

np.random.seed(42)
data = pd.DataFrame(np.random.randn(100, 24), columns=[f'Column_{i}' for i in range(24)])

# Defining the number of columns in the dataset

num_columns = len(data.columns)

# Setting up subplots for multiple distribution plots

fig, axes = plt.subplots(nrows=num_columns, ncols=1, figsize=(8, 2*num_columns))
plt.subplots_adjust(hspace=0.5)

# Create distribution plots for each column using a for loop

for i, column in enumerate(data.columns):
    ax = axes[i]
    sns.histplot(data=data, x=column, kde=True,ax=ax)
    ax.set_xlabel(column)
    ax.set_ylabel('Count')

# Show the plots
plt.show()

# %%
#Identifying numerical and catagorical value
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 24 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Column_0   100 non-null    float64
#  1   Column_1   100 non-null    float64
#  2   Column_2   100 non-null    float64
#  3   Column_3   100 non-null    float64
#  4   Column_4   100 non-null    float64
#  5   Column_5   100 non-null    float64
#  6   Column_6   100 non-null    float64
#  7   Column_7   100 non-null    float64
#  8   Column_8   100 non-null    float64
#  9   Column_9   100 non-null    float64
#  10  Column_10  100 non-null    float64
#  11  Column_11  100 non-null    float64
#  12  Column_12  100 non-null    float64
#  13  Column_13  100 non-null    float64
#  14  Column_14  100 non-null    float64
#  15  Column_15  100 non-null    float64
#  16  Column_16  100 non-null    float64
#  17  Column_17  100 non-null    float64
#  18  Column_18  100 non-null    float64
# ...

# %%
#In order to make list of continous parameters
cont_var=[var for var in data.columns if data[var].dtype!='O']

# %%
#How to find outliers
pd.set_option('display.max_columns',50)
data.describe()
# Out:
#          Column_0    Column_1    Column_2    Column_3    Column_4    Column_5  \
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean     0.016814    0.014875   -0.070947    0.104157   -0.009920    0.091162
# std      0.797752    1.016189    1.021369    1.013363    0.961413    1.009669
# min     -2.211862   -2.003862   -2.619745   -2.940389   -1.993736   -2.848543
# 25%     -0.445774   -0.731111   -0.753684   -0.498054   -0.670298   -0.437441
# 50%      0.079435   -0.079500    0.102291    0.198274   -0.033535    0.068516
# 75%      0.445791    0.753649    0.608236    0.824809    0.624757    0.855316
# max      2.013387    3.109919    1.848956    2.558199    2.319330    2.252436
#
#          Column_6    Column_7    Column_8    Column_9   Column_10   Column_11  \
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean     0.095648   -0.096266    0.012760    0.178500   -0.087613    0.067066
# ...

# %%
data['Column_1'].unique()
# Out:
# array([-1.38264301e-01,  1.10922590e-01, -1.76304016e+00,  1.56464366e+00,
#         2.61055272e-01, -9.09387455e-01,  7.81822872e-01, -7.53736164e-01,
#        -1.24573878e+00, -2.36818607e-01, -1.14736441e-01, -1.24778318e+00,
#        -6.22699520e-01,  8.13509636e-01, -3.21385842e-01,  1.53273891e+00,
#         1.50393786e-01,  5.14438834e-01,  7.17542256e-01, -1.03524232e+00,
#        -9.55540441e-01, -4.87125384e-01, -9.04316625e-01,  2.54420843e-01,
#         7.70865194e-01, -9.22165324e-01, -5.11215676e-01,  6.96206365e-01,
#        -3.71440866e-01, -1.25111358e+00, -1.71016839e+00, -7.25743813e-01,
#         1.81244856e+00, -1.27674858e+00,  8.89630796e-01,  6.74819492e-01,
#        -3.87701560e-01,  1.10870358e+00,  1.57745328e+00,  7.08356447e-01,
#         1.32915253e+00, -1.15836469e+00, -5.35235212e-01,  6.47195940e-01,
#         1.17272902e+00, -3.49257704e-01, -1.03990593e+00,  3.28762410e-01,
# ...

# %%
data['Column_1'].value_counts()
# Out:
# -0.138264    1
# -1.866537    1
# -1.830633    1
#  1.838184    1
# -0.241258    1
#             ..
# -1.710168    1
# -1.251114    1
# -0.371441    1
#  0.696206    1
# -1.326048    1
# Name: Column_1, Length: 100, dtype: int64

# %%
data['Column_1'].value_counts().sort_index()
# Out:
# -2.003862    1
# -1.866537    1
# -1.830633    1
# -1.763040    1
# -1.710168    1
#             ..
#  1.577453    1
#  1.598647    1
#  1.812449    1
#  1.838184    1
#  3.109919    1
# Name: Column_1, Length: 100, dtype: int64

# %%
#This will be representated by bivariete analysis
plt.scatter(data['Column_1'], data['Column_2'])

# %%
data=data[(data.Column_1>-2)&(data.Column_2<3)]
plt.scatter(data['Column_1'], data['Column_2'])

# %%
sum(data['Column_1']<=3)
sum(data['Column_2']>=-2)
data=data[(data.Column_1>=-2)&(data.Column_2<=3)]
plt.figure(figsize=(15,6))
plt.scatter(data['Column_1'], data['Column_2'])

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.displot(data.corr(), bins=10)

# %%
sns.boxplot(data['Column_1'])
# Out:
# <AxesSubplot:xlabel='Column_1'>

# %%
sns.boxplot(data['Column_2'])
# Out:
# C:\Users\radhi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Column_2'>

# %%
sns.boxplot(data['Column_0'])
# Out:
# C:\Users\radhi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Column_0'>

# %%
#Input and output is continous- Scatter plot
#One is catagorical and another is numerical - barplot , boxplot
#Univariete analysis of catagorical variable: countplot
#Bivariete analysis: Both x and y are catagorical(countplot along with hue parameter)

# %%
#Bivariete Analysis
plt.scatter(data['Column_1'], data['Column_2'])
plt.title('Column_1')
plt.xlabel('Column_1')
plt.ylabel('Column_2')
plt.show()

# %%
#line plot
plt.plot(data['Column_1'], data['Column_2'])

# %%
data.drop_duplicates(inplace=True)

# %%
data.shape
# Out:
# (99, 24)

# %%
#working on missing values
data.isna().sum()
# Out:
# Column_0     0
# Column_1     0
# Column_2     0
# Column_3     0
# Column_4     0
# Column_5     0
# Column_6     0
# Column_7     0
# Column_8     0
# Column_9     0
# Column_10    0
# Column_11    0
# Column_12    0
# Column_13    0
# Column_14    0
# Column_15    0
# Column_16    0
# Column_17    0
# Column_18    0
# Column_19    0
# Column_20    0
# Column_21    0
# Column_22    0
# Column_23    0
# dtype: int64
